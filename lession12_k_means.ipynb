# %%
import numpy as np
from sklearn.cluster import KMeans

X = np.array([
    [1, 2],
    [1, 3],
    [2, 2],
    [8, 8],
    [9, 8],
    [8, 9],
    [20, 20],
    [21, 20],
    [20, 21]
])

model = KMeans(
    n_clusters=3,
    random_state=42
)

model.fit(X)

print(model.labels_)
# Out:
# [2 2 2 0 0 0 1 1 1]

# %%
print(model.cluster_centers_)
# Out:
# [[ 8.33333333  8.33333333]
#  [20.33333333 20.33333333]
#  [ 1.33333333  2.33333333]]

# %%
new_point = [[2, 3]]
model.predict(new_point)
# Out:
# array([2], dtype=int32)

# %%
labels = model.fit_predict(X)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

model = KMeans(
    n_clusters=3,
    random_state=42
)

labels = model.fit_predict(X_scaled)

# %%
from sklearn.cluster import KMeans

for k in range(1, 10):

    model = KMeans(
        n_clusters=k,
        random_state=42
    )

    model.fit(X_scaled)

    print(k, model.inertia_)
# Out:
# 1 18.0
# 2 3.631337782626579
# 3 0.1955420396755812
# 4 0.16295014321327186
# 5 0.11571782840001987
# 6 0.09045447165237422
# 7 0.04322215683912227
# 8 0.017958800091476573
# 9 0.0

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

X = np.array([
    [1, 2],
    [1, 3],
    [2, 2],
    [8, 8],
    [9, 8],
    [8, 9],
    [20, 20],
    [21, 20],
    [20, 21]
])

model = KMeans(
    n_clusters=3,
    random_state=42
)

labels = model.fit_predict(X)

plt.scatter(
    X[:, 0],
    X[:, 1],
    c=labels
)

plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("K-Means Clustering")

plt.show()

# %%
centroids = model.cluster_centers_

plt.scatter(
    X[:, 0],
    X[:, 1],
    c=labels
)

plt.scatter(
    centroids[:, 0],
    centroids[:, 1],
    marker="X",
    s=200
)

plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("K-Means with Centroids")

plt.show()

# %%
inertias = []

for k in range(1, 10):

    model = KMeans(
        n_clusters=k,
        random_state=42
    )

    model.fit(X)

    inertias.append(model.inertia_)

# %%
plt.plot(
    range(1, 10),
    inertias,
    marker="o"
)

plt.xlabel("Number of Clusters (K)")
plt.ylabel("Inertia")
plt.title("Elbow Method")

plt.show()

# %%
from sklearn.metrics import silhouette_score
model = KMeans(
    n_clusters=3,
    random_state=42
)

labels = model.fit_predict(X)

score = silhouette_score(X, labels)

print("Silhouette Score:", score)
# Out:
# Silhouette Score: 0.8956354622921443

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

for k in range(2, 9):

    model = KMeans(
        n_clusters=k,
        random_state=42
    )

    labels = model.fit_predict(X)

    score = silhouette_score(X, labels)

    print(
        "K:",
        k,
        "Silhouette Score:",
        score
    )
# Out:
# K: 2 Silhouette Score: 0.7879557032803043
# K: 3 Silhouette Score: 0.8956354622921443
# K: 4 Silhouette Score: 0.6171440037842443
# K: 5 Silhouette Score: 0.35673962473819787
# K: 6 Silhouette Score: 0.3236870957707658
# K: 7 Silhouette Score: 0.06508738195854501
# K: 8 Silhouette Score: 0.032543690979272503

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

data = {
    "income": [20, 22, 25, 70, 72, 75, 40, 42, 45],
    "spending_score": [80, 85, 78, 20, 25, 18, 50, 55, 52]
}

df = pd.DataFrame(data)

X = df[
    [
        "income",
        "spending_score"
    ]
]

# %%
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
model = KMeans(
    n_clusters=3,
    random_state=42
)

# %%
labels = model.fit_predict(X_scaled)

# %%
df["cluster"] = labels

# %%
print(df)
# Out:
#    income  spending_score  cluster
# 0      20              80        1
# 1      22              85        1
# 2      25              78        1
# 3      70              20        0
# 4      72              25        0
# 5      75              18        0
# 6      40              50        2
# 7      42              55        2
# 8      45              52        2

# %%
from sklearn.cluster import KMeans
import numpy as np 

X = [
    [1, 2],
    [1, 3],
    [2, 2],
    [8, 8],
    [9, 8],
    [8, 9],
    [20, 20],
    [21, 20],
    [20, 21]
]
model=KMeans(
    n_clusters=3,
    random_state=42
)
model.fit(X)
print(model.labels_)
# Out:
# [2 2 2 0 0 0 1 1 1]

# %%
print(model.cluster_centers_)
# Out:
# [[ 8.33333333  8.33333333]
#  [20.33333333 20.33333333]
#  [ 1.33333333  2.33333333]]
